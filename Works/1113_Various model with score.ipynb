# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
import warnings
warnings.filterwarnings('ignore')

import re
import seaborn as sb

# Tools for creating ngrams and vectorizing input data
from konlpy.tag import Mecab
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras import Input, Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional, Embedding, Conv1D, MaxPooling1D, BatchNormalization, Concatenate, Layer, GlobalMaxPool1D, GlobalMaxPooling1D, GlobalAveragePooling1D, GRU, SpatialDropout1D
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras import initializers, regularizers, constraints, optimizers, layers
import os
from keras import backend as K
from gensim.models import FastText
from sklearn.neighbors import NearestNeighbors

# %%
class Attention(Layer):
    def __init__(self, step_dim, W_regularizer=None, b_regularizer=None, W_constraint=None, b_constraint=None, bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim  

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
#Remove morphemes from specific parts-of-speech
def pos_delete(tag, pos):
  for p in pos:
    if (p not in tag) == False:
      if 'VV+' not in tag:
        return False
      else:
        return True
    else:
      continue
  
  return True

#Parts-of-speech list
POS = ['CP', 'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ', 'JX', 'JC', 'JO', 'EP', 'EF', 'EC', 'ETN', 'ETM', 'VCP', 'VCN', 'SF', 'SY', 'XSN', 'XSV', 'XSA', 'XR']

#Vectorized using a trained FastText model
def vectorize_data(data, vocab: dict) -> list:
  keys = list(vocab.keys())
  filter_unknown = lambda word: vocab.get(word, None) is not None
  result = []
  for d in data:
    filtered = list(filter(filter_unknown,d))
    res = []
    for f in filtered:
      res.append(vocab[f].index)
    result.append(res)
  
  return result

#Build model
def build_attention(embedding_matrix, maxlen):
  sequence_input = Input(shape=(maxlen,), dtype='int32')
  embedded_sequences = Embedding(embedding_matrix.shape[0], embedding_matrix.shape[1],  input_length=maxlen, weights=[embedding_matrix], trainable=False)(sequence_input)
  dropout_1 = SpatialDropout1D(0.1)(embedded_sequences)
  bilstm = Bidirectional(LSTM(32, return_sequences=True))(dropout_1)
  bigru = Bidirectional(GRU(32, return_sequences=True))(bilstm)

  atten_1 = Attention(maxlen)(bilstm)
  atten_2 = Attention(maxlen)(bigru)
  avg_pool = GlobalAveragePooling1D()(bigru)
  max_pool = GlobalMaxPooling1D()(bigru)

  conc = concatenate([atten_1, atten_2, avg_pool, max_pool])
  dense = Dense(16, activation='relu')(conc)
  dropout_2 = Dropout(0.1)(dense)
  output = Dense(1, activation='sigmoid')(dropout_2)

  model = Model(inputs=sequence_input, outputs=output)
  model.summary()

  return model

def build_1dcnn(embedding_matrix, maxlen):
    model = Sequential()
    model.add(Embedding(input_dim = embedding_matrix.shape[0], output_dim = embedding_matrix.shape[1],  input_length = maxlen, weights = [embedding_matrix], trainable=False))
    model.add(Dropout(0.2))
    model.add(Conv1D(50, 5, strides=1, padding='valid', activation='relu'))
    model.add(GlobalMaxPooling1D())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()

    return model

def build_bilstm(embedding_matrix, maxlen):
    model = Sequential()
    model.add(Embedding(input_dim = embedding_matrix.shape[0], output_dim = embedding_matrix.shape[1],  input_length = maxlen, weights = [embedding_matrix], trainable=False))
    model.add(Bidirectional(LSTM(128, recurrent_dropout=0.1)))
    model.add(Dropout(0.25))
    model.add(Dense(64))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()

    return model

def build_bilstm_dbl(embedding_matrix, maxlen):
    model = Sequential()
    model.add(Embedding(input_dim = embedding_matrix.shape[0], output_dim = embedding_matrix.shape[1],  input_length = maxlen, weights = [embedding_matrix], trainable=False))
    model.add(Bidirectional(LSTM(128, recurrent_dropout=0.1, return_sequences=True)))
    model.add(Bidirectional(LSTM(64, recurrent_dropout=0.1)))
    model.add(Dropout(0.25))
    model.add(Dense(64))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()

    return model
  
#Make synonym dictionary
def make_synonyms():
  synonyms_number = 5
  word_number = 20000
  embed_mat = ft_model.wv.vectors
  nn = NearestNeighbors(n_neighbors=synonyms_number+1).fit(embed_mat)
  neighbours_mat = nn.kneighbors(embed_mat[1:word_number])[1]
  nei_mat = []

  for i in range(len(neighbours_mat)):
    tmp = [ft_model.wv.index2word[s] for s in neighbours_mat[i]]
    nei_mat.append(tmp)

  synonyms = {nei[0]: nei[1:] for nei in nei_mat}

  return synonyms

#Modify train sentence with synonym dictionary
def modify_sentence(X_pos, synonyms, p=0.5):
    sentence = [ft_model.wv.index2word[x] for x in np.trim_zeros(X_pos)]
    for i in range(len(sentence)):
        if np.random.random() > p:
            try:
                syns = synonyms[sentence[i]]
                sentence[i] = np.random.choice(syns)
            except KeyError:
                pass
    return sentence

#Final function. Generate new hate sentence with synonym dictionary (with modify_sentence function)
def text_generator(X_pad, y_data, synonyms):
  X_pos = X_pad[y_data==1]
  n_texts = 15000
  indexes = np.random.randint(0, X_pos.shape[0], n_texts)
  
  X_gen = np.array([modify_sentence(x, synonyms) for x in X_pos[indexes]])
  y_gen = np.ones(n_texts)

  split_X_gen = []
  for i in range(len(X_gen)):
    split_X_gen.append([gen for gen in X_gen[i]])

  return split_X_gen, y_gen

#Text tokenize function (To use Predictor function)
def text_tokenize(text):
  mecab = Mecab()
  train_tokenized = []

  ps = mecab.pos(text)
  tagged = []
  for p in ps:
    if pos_delete(p[1], POS):
      tagged.append(p[0])
  temp_X = [word for word in tagged]
  train_tokenized.append(temp_X)

  return train_tokenized

#Visulaize confusion matrix
def plot_confusion_matrix(y_true, y_pred, ax, class_names, vmax=None,
                          normed=True, title='Confusion matrix'):
    matrix = confusion_matrix(y_true,y_pred)
    if normed:
        matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
    sb.heatmap(matrix, vmax=vmax, annot=True, square=True, ax=ax,
               cmap=plt.cm.Blues_r, cbar=False, linecolor='black',
               linewidths=1, xticklabels=class_names)
    ax.set_title(title, y=1.20, fontsize=16)
    ax.set_xlabel('Predicted labels', y=1.10, fontsize=12)
    ax.set_yticklabels(class_names, rotation=0)

#Convert to probability corresponding to each label
def predict_proba(pred):
  proba = []
  for i in range(len(pred)):
    proba.append([float(1-pred[i]), pred[i][0]])
  
  return proba

#Class prediction based on the transformed probability
def class_predict(proba):
  return np.argmax(proba, axis=1)

#Determine max_len function
def below_threshold_len(max_len, nested_list):
  count = 0
  for sentence in nested_list:
    if(len(sentence) <= max_len):
        count = count + 1
  print('Proportion of samples with length %s or less among all samples: %s'%(max_len, (count / len(nested_list))*100))

# %%
#Train data load +  Tagging + Spliting + FastText Model load
train_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/train_data.csv', encoding='cp949')
train_data['comments'] = train_data['comments'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]','')

mecab = Mecab()
train_tokenized = []

for comment in train_data['comments']:
  ps = mecab.pos(comment)
  tagged = []
  for p in ps:
    if pos_delete(p[1], POS):
      tagged.append(p[0])
    temp_X = [word for word in tagged]
  train_tokenized.append(temp_X)

ft_model = FastText.load('/content/drive/MyDrive/Colab Notebooks/model/fasttext_310k_1109.model')

# %%
#Make Synonyms dictionary
synonyms = make_synonyms()

# %%
#Define X_data and y_data
X_data = train_tokenized
y_data = train_data['hate'].values

# %%
#View Ratio Length
below_threshold_len(35, X_data)
# Out:
# Proportion of samples with length 35 or less among all samples: 98.89632936507937

# %%
#Comment Vectorize with FastText Model (train_data)
max_len = 35
padded_X = pad_sequences(
    sequences=vectorize_data(X_data, vocab=ft_model.wv.vocab),
    maxlen=max_len,
    padding='post'
)

# %%
#Generate Sentence with synonym dictionary
X_pos = padded_X[y_data==1]
split_X_gen, y_gen = text_generator(padded_X, y_data, synonyms)
mix_X = X_data + split_X_gen
mix_y = np.hstack((y_data, y_gen))

#Comment Vectorize with FastText Model (Generate_data)
max_len = 35
X_pad = pad_sequences(
    sequences=vectorize_data(mix_X, vocab=ft_model.wv.vocab),
    maxlen=max_len,
    padding='post'
)

#Final Input data: X_pad(x_data), mix_y(y_data)

# %%
#Split train data, validation data and test data
X_train, X_vt, y_train, y_vt = train_test_split(X_pad, mix_y, test_size=0.2, shuffle=True, random_state=42)
X_valid, X_test, y_valid, y_test = train_test_split(X_vt, y_vt, test_size=0.3, shuffle=True, random_state=42)

# %%
#Define matrics(TP, FP, TN, FN, Accuracy, Precision, Recall, AUC)
METRICS = [
    keras.metrics.BinaryAccuracy(name='accuracy'),
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

# %%
#Model define and train, visualize model tree
attention = build_attention(embedding_matrix=ft_model.wv.vectors, maxlen=max_len)
cnn = build_1dcnn(embedding_matrix=ft_model.wv.vectors, maxlen=max_len)
bilstm = build_bilstm(embedding_matrix=ft_model.wv.vectors, maxlen=max_len)
bilstm_dbl = build_bilstm_dbl(embedding_matrix=ft_model.wv.vectors, maxlen=max_len)

attention.compile(loss='binary_crossentropy', optimizer='adam', metrics=METRICS)
cnn.compile(loss='binary_crossentropy', optimizer='adam', metrics=METRICS)
bilstm.compile(loss='binary_crossentropy', optimizer='adam', metrics=METRICS)
bilstm_dbl.compile(loss='binary_crossentropy', optimizer='adam', metrics=METRICS)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 35)]         0           []
#
#  embedding (Embedding)          (None, 35, 100)      9236500     ['input_1[0][0]']
#
#  spatial_dropout1d (SpatialDrop  (None, 35, 100)     0           ['embedding[0][0]']
#  out1D)
#
#  bidirectional (Bidirectional)  (None, 35, 64)       34048       ['spatial_dropout1d[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 35, 64)      18816       ['bidirectional[0][0]']
#  )
#
#  attention (Attention)          (None, 64)           99          ['bidirectional[0][0]']
#
#  attention_1 (Attention)        (None, 64)           99          ['bidirectional_1[0][0]']
#
#  global_average_pooling1d (Glob  (None, 64)          0           ['bidirectional_1[0][0]']
#  alAveragePooling1D)
#
#  global_max_pooling1d (GlobalMa  (None, 64)          0           ['bidirectional_1[0][0]']
#  xPooling1D)
#
#  concatenate (Concatenate)      (None, 256)          0           ['attention[0][0]',
#                                                                   'attention_1[0][0]',
#                                                                   'global_average_pooling1d[0][0]'
#                                                                  , 'global_max_pooling1d[0][0]']
#
#  dense (Dense)                  (None, 16)           4112        ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 16)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1)            17          ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 9,293,691
# Trainable params: 57,191
# Non-trainable params: 9,236,500
# __________________________________________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 35, 100)           9236500
#
#  dropout_1 (Dropout)         (None, 35, 100)           0
#
#  conv1d (Conv1D)             (None, 31, 50)            25050
#
#  global_max_pooling1d_1 (Glo  (None, 50)               0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (None, 64)                3264
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9,264,879
# Trainable params: 28,379
# Non-trainable params: 9,236,500
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 35, 100)           9236500
#
#  bidirectional_2 (Bidirectio  (None, 256)              234496
#  nal)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 64)                16448
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9,487,509
# Trainable params: 251,009
# Non-trainable params: 9,236,500
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 35, 100)           9236500
#
#  bidirectional_3 (Bidirectio  (None, 35, 256)          234496
#  nal)
#
#  bidirectional_4 (Bidirectio  (None, 128)              164352
#  nal)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9,643,669
# Trainable params: 407,169
# Non-trainable params: 9,236,500
# _________________________________________________________________

# %%
keras.utils.plot_model(attention, show_shapes=True, dpi=90)

# %%
keras.utils.plot_model(cnn, show_shapes=True, dpi=90)

# %%
keras.utils.plot_model(bilstm, show_shapes=True, dpi=90)

# %%
keras.utils.plot_model(bilstm_dbl, show_shapes=True, dpi=90)

# %%
h_attention = attention.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=100, epochs=10)
h_cnn = cnn.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=100, epochs=10)
h_bilstm = bilstm.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=100, epochs=10)
h_bilstm_dbl = bilstm_dbl.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=100, epochs=10)

print('Model train complete.')
# Out:
# Epoch 1/10
# 314/314 [==============================] - 28s 67ms/step - loss: 0.4565 - accuracy: 0.7816 - precision: 0.7893 - recall: 0.7717 - val_loss: 0.3456 - val_accuracy: 0.8564 - val_precision: 0.8501 - val_recall: 0.8685
# Epoch 2/10
# 314/314 [==============================] - 20s 63ms/step - loss: 0.3616 - accuracy: 0.8440 - precision: 0.8430 - recall: 0.8475 - val_loss: 0.2990 - val_accuracy: 0.8733 - val_precision: 0.8768 - val_recall: 0.8714
# Epoch 3/10
# 314/314 [==============================] - 20s 63ms/step - loss: 0.3213 - accuracy: 0.8616 - precision: 0.8612 - recall: 0.8640 - val_loss: 0.2789 - val_accuracy: 0.8850 - val_precision: 0.8927 - val_recall: 0.8776
# Epoch 4/10
# 314/314 [==============================] - 20s 63ms/step - loss: 0.2836 - accuracy: 0.8806 - precision: 0.8829 - recall: 0.8793 - val_loss: 0.2528 - val_accuracy: 0.8936 - val_precision: 0.8940 - val_recall: 0.8953
# Epoch 5/10
# 314/314 [==============================] - 20s 62ms/step - loss: 0.2560 - accuracy: 0.8923 - precision: 0.8966 - recall: 0.8882 - val_loss: 0.2721 - val_accuracy: 0.8863 - val_precision: 0.8428 - val_recall: 0.9523
# Epoch 6/10
# 314/314 [==============================] - 20s 63ms/step - loss: 0.2410 - accuracy: 0.8994 - precision: 0.9020 - recall: 0.8976 - val_loss: 0.2316 - val_accuracy: 0.9036 - val_precision: 0.8857 - val_recall: 0.9289
# Epoch 7/10
# 314/314 [==============================] - 20s 62ms/step - loss: 0.2247 - accuracy: 0.9091 - precision: 0.9118 - recall: 0.9070 - val_loss: 0.2300 - val_accuracy: 0.9030 - val_precision: 0.8775 - val_recall: 0.9390
# Epoch 8/10
# 314/314 [==============================] - 20s 63ms/step - loss: 0.2122 - accuracy: 0.9129 - precision: 0.9147 - recall: 0.9119 - val_loss: 0.2221 - val_accuracy: 0.9056 - val_precision: 0.8990 - val_recall: 0.9159
# Epoch 9/10
# 314/314 [==============================] - 20s 63ms/step - loss: 0.2014 - accuracy: 0.9201 - precision: 0.9218 - recall: 0.9191 - val_loss: 0.2157 - val_accuracy: 0.9112 - val_precision: 0.9009 - val_recall: 0.9260
# Epoch 10/10
# 314/314 [==============================] - 20s 63ms/step - loss: 0.1912 - accuracy: 0.9225 - precision: 0.9229 - recall: 0.9229 - val_loss: 0.2281 - val_accuracy: 0.9058 - val_precision: 0.8867 - val_recall: 0.9325
# Epoch 1/10
# 314/314 [==============================] - 6s 17ms/step - loss: 0.4599 - accuracy: 0.8061 - precision: 0.8131 - recall: 0.7979 - val_loss: 0.3584 - val_accuracy: 0.8547 - val_precision: 0.8235 - val_recall: 0.9065
# Epoch 2/10
# 314/314 [==============================] - 5s 16ms/step - loss: 0.3719 - accuracy: 0.8377 - precision: 0.8379 - recall: 0.8396 - val_loss: 0.3324 - val_accuracy: 0.8629 - val_precision: 0.8242 - val_recall: 0.9260
# Epoch 3/10
# 314/314 [==============================] - 5s 16ms/step - loss: 0.3357 - accuracy: 0.8557 - precision: 0.8549 - recall: 0.8589 - val_loss: 0.3082 - val_accuracy: 0.8724 - val_precision: 0.8313 - val_recall: 0.9375
# Epoch 4/10
# 314/314 [==============================] - 5s 16ms/step - loss: 0.3042 - accuracy: 0.8712 - precision: 0.8703 - recall: 0.8742 - val_loss: 0.3221 - val_accuracy: 0.8578 - val_precision: 0.7975 - val_recall: 0.9628
# Epoch 5/10
# 314/314 [==============================] - 5s 16ms/step - loss: 0.2819 - accuracy: 0.8817 - precision: 0.8818 - recall: 0.8831 - val_loss: 0.2824 - val_accuracy: 0.8786 - val_precision: 0.8424 - val_recall: 0.9343
# Epoch 6/10
# 314/314 [==============================] - 5s 16ms/step - loss: 0.2658 - accuracy: 0.8890 - precision: 0.8892 - recall: 0.8903 - val_loss: 0.2836 - val_accuracy: 0.8830 - val_precision: 0.8386 - val_recall: 0.9512
# Epoch 7/10
# 314/314 [==============================] - 5s 16ms/step - loss: 0.2434 - accuracy: 0.9000 - precision: 0.9018 - recall: 0.8990 - val_loss: 0.2864 - val_accuracy: 0.8810 - val_precision: 0.8317 - val_recall: 0.9581
# Epoch 8/10
# 314/314 [==============================] - 5s 16ms/step - loss: 0.2351 - accuracy: 0.9028 - precision: 0.9031 - recall: 0.9038 - val_loss: 0.2684 - val_accuracy: 0.8919 - val_precision: 0.8498 - val_recall: 0.9545
# Epoch 9/10
# 314/314 [==============================] - 5s 16ms/step - loss: 0.2227 - accuracy: 0.9074 - precision: 0.9080 - recall: 0.9079 - val_loss: 0.3289 - val_accuracy: 0.8646 - val_precision: 0.8024 - val_recall: 0.9707
# Epoch 10/10
# 314/314 [==============================] - 5s 16ms/step - loss: 0.2128 - accuracy: 0.9098 - precision: 0.9102 - recall: 0.9104 - val_loss: 0.3003 - val_accuracy: 0.8786 - val_precision: 0.8254 - val_recall: 0.9632
# Epoch 1/10
# 314/314 [==============================] - 62s 184ms/step - loss: 0.4191 - accuracy: 0.8201 - precision: 0.8202 - recall: 0.8227 - val_loss: 0.3491 - val_accuracy: 0.8577 - val_precision: 0.8413 - val_recall: 0.8848
# Epoch 2/10
# 314/314 [==============================] - 58s 183ms/step - loss: 0.3554 - accuracy: 0.8446 - precision: 0.8463 - recall: 0.8442 - val_loss: 0.3375 - val_accuracy: 0.8560 - val_precision: 0.8966 - val_recall: 0.8079
# Epoch 3/10
# 314/314 [==============================] - 57s 182ms/step - loss: 0.3208 - accuracy: 0.8605 - precision: 0.8619 - recall: 0.8605 - val_loss: 0.2829 - val_accuracy: 0.8843 - val_precision: 0.8718 - val_recall: 0.9036
# Epoch 4/10
# 314/314 [==============================] - 57s 183ms/step - loss: 0.2902 - accuracy: 0.8759 - precision: 0.8780 - recall: 0.8748 - val_loss: 0.2648 - val_accuracy: 0.8908 - val_precision: 0.9039 - val_recall: 0.8769
# Epoch 5/10
# 314/314 [==============================] - 58s 184ms/step - loss: 0.2626 - accuracy: 0.8891 - precision: 0.8932 - recall: 0.8854 - val_loss: 0.2553 - val_accuracy: 0.8932 - val_precision: 0.8689 - val_recall: 0.9285
# Epoch 6/10
# 314/314 [==============================] - 58s 183ms/step - loss: 0.2391 - accuracy: 0.9006 - precision: 0.9040 - recall: 0.8976 - val_loss: 0.2367 - val_accuracy: 0.9043 - val_precision: 0.9237 - val_recall: 0.8834
# Epoch 7/10
# 314/314 [==============================] - 57s 182ms/step - loss: 0.2221 - accuracy: 0.9067 - precision: 0.9104 - recall: 0.9033 - val_loss: 0.2267 - val_accuracy: 0.9080 - val_precision: 0.9262 - val_recall: 0.8884
# Epoch 8/10
# 314/314 [==============================] - 58s 186ms/step - loss: 0.2059 - accuracy: 0.9140 - precision: 0.9194 - recall: 0.9086 - val_loss: 0.2262 - val_accuracy: 0.9118 - val_precision: 0.9141 - val_recall: 0.9108
# Epoch 9/10
# 314/314 [==============================] - 59s 187ms/step - loss: 0.1924 - accuracy: 0.9213 - precision: 0.9260 - recall: 0.9168 - val_loss: 0.2189 - val_accuracy: 0.9127 - val_precision: 0.9052 - val_recall: 0.9238
# Epoch 10/10
# 314/314 [==============================] - 59s 189ms/step - loss: 0.1787 - accuracy: 0.9273 - precision: 0.9314 - recall: 0.9236 - val_loss: 0.2185 - val_accuracy: 0.9105 - val_precision: 0.9127 - val_recall: 0.9097
# Epoch 1/10
# 314/314 [==============================] - 113s 335ms/step - loss: 0.4193 - accuracy: 0.8219 - precision: 0.8235 - recall: 0.8223 - val_loss: 0.3591 - val_accuracy: 0.8442 - val_precision: 0.8804 - val_recall: 0.7999
# Epoch 2/10
# 314/314 [==============================] - 103s 329ms/step - loss: 0.3384 - accuracy: 0.8527 - precision: 0.8509 - recall: 0.8573 - val_loss: 0.2895 - val_accuracy: 0.8781 - val_precision: 0.8936 - val_recall: 0.8610
# Epoch 3/10
# 314/314 [==============================] - 104s 333ms/step - loss: 0.2924 - accuracy: 0.8753 - precision: 0.8747 - recall: 0.8778 - val_loss: 0.2615 - val_accuracy: 0.8961 - val_precision: 0.8881 - val_recall: 0.9086
# Epoch 4/10
# 314/314 [==============================] - 104s 332ms/step - loss: 0.2529 - accuracy: 0.8944 - precision: 0.8971 - recall: 0.8924 - val_loss: 0.2488 - val_accuracy: 0.9001 - val_precision: 0.9253 - val_recall: 0.8725
# Epoch 5/10
# 314/314 [==============================] - 105s 336ms/step - loss: 0.2245 - accuracy: 0.9071 - precision: 0.9092 - recall: 0.9056 - val_loss: 0.2444 - val_accuracy: 0.8994 - val_precision: 0.9074 - val_recall: 0.8917
# Epoch 6/10
# 314/314 [==============================] - 105s 335ms/step - loss: 0.2043 - accuracy: 0.9148 - precision: 0.9186 - recall: 0.9114 - val_loss: 0.2220 - val_accuracy: 0.9047 - val_precision: 0.9016 - val_recall: 0.9104
# Epoch 7/10
# 314/314 [==============================] - 105s 334ms/step - loss: 0.1834 - accuracy: 0.9251 - precision: 0.9287 - recall: 0.9219 - val_loss: 0.2499 - val_accuracy: 0.9005 - val_precision: 0.9283 - val_recall: 0.8700
# Epoch 8/10
# 314/314 [==============================] - 105s 335ms/step - loss: 0.1702 - accuracy: 0.9300 - precision: 0.9341 - recall: 0.9261 - val_loss: 0.2159 - val_accuracy: 0.9096 - val_precision: 0.9239 - val_recall: 0.8945
# Epoch 9/10
# 314/314 [==============================] - 105s 333ms/step - loss: 0.1538 - accuracy: 0.9380 - precision: 0.9413 - recall: 0.9351 - val_loss: 0.2187 - val_accuracy: 0.9100 - val_precision: 0.9233 - val_recall: 0.8960
# Epoch 10/10
# 314/314 [==============================] - 105s 334ms/step - loss: 0.1427 - accuracy: 0.9428 - precision: 0.9453 - recall: 0.9408 - val_loss: 0.2338 - val_accuracy: 0.9087 - val_precision: 0.9079 - val_recall: 0.9115
# Model train complete.

# %%
train_pred_a = attention.predict(X_train)
test_pred_a = attention.predict(X_test)
train_pred_c = cnn.predict(X_train)
test_pred_c = cnn.predict(X_test)
train_pred_b = bilstm.predict(X_train)
test_pred_b = bilstm.predict(X_test)
train_pred_bd = bilstm_dbl.predict(X_train)
test_pred_bd = bilstm_dbl.predict(X_test)

train_pred_proba_a = predict_proba(train_pred_a)
test_pred_proba_a = predict_proba(test_pred_a)
train_pred_proba_c = predict_proba(train_pred_c)
test_pred_proba_c = predict_proba(test_pred_c)
train_pred_proba_b = predict_proba(train_pred_b)
test_pred_proba_b = predict_proba(test_pred_b)
train_pred_proba_bd = predict_proba(train_pred_bd)
test_pred_proba_bd = predict_proba(test_pred_bd)

train_preds_a = class_predict(train_pred_proba_a)
test_preds_a = class_predict(test_pred_proba_a)
train_preds_c = class_predict(train_pred_proba_c)
test_preds_c = class_predict(test_pred_proba_c)
train_preds_b = class_predict(train_pred_proba_b)
test_preds_b = class_predict(test_pred_proba_b)
train_preds_bd = class_predict(train_pred_proba_bd)
test_preds_bd = class_predict(test_pred_proba_bd)

print('Data predict complete.')
# Out:
# Data predict complete.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (classification_report,
                             confusion_matrix,
                             roc_auc_score)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

report_a = classification_report(y_test, test_preds_a)
report_c = classification_report(y_test, test_preds_c)
report_b = classification_report(y_test, test_preds_b)
report_bd = classification_report(y_test, test_preds_bd)
print('Attantion Model Classification Report')
print(report_a)
print('1D-CNN Model Classification Report')
print(report_c)
print('BiLSTM Model Classification Report')
print(report_b)
print('Double-BiLSTM Moded Classification Report')
print(report_bd)


def plot_cm(labels, predictions, name, p=0.5):
    cm = confusion_matrix(labels, predictions)
    plt.figure(figsize=(5, 5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title("Confusion matrix (" + name + ')')
    plt.ylabel("Actual label")
    plt.xlabel("Predicted label")
    
plot_cm(y_test, test_preds_a, 'Attention')
plot_cm(y_test, test_preds_c, '1D-CNN')
plot_cm(y_test, test_preds_b, 'BiLSTM')
plot_cm(y_test, test_preds_bd, 'Double BiLSTM')
# Out:
# Attantion Model Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.89      0.91      1207
#          1.0       0.89      0.93      0.91      1145
#
#     accuracy                           0.91      2352
#    macro avg       0.91      0.91      0.91      2352
# weighted avg       0.91      0.91      0.91      2352
#
# 1D-CNN Model Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.80      0.88      1207
#          1.0       0.82      0.97      0.89      1145
#
#     accuracy                           0.88      2352
#    macro avg       0.89      0.88      0.88      2352
# weighted avg       0.89      0.88      0.88      2352
#
# BiLSTM Model Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.92      0.92      1207
#          1.0       0.92      0.92      0.92      1145
#
#     accuracy                           0.92      2352
#    macro avg       0.92      0.92      0.92      2352
# weighted avg       0.92      0.92      0.92      2352
#
# Double-BiLSTM Moded Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.92      1207
#          1.0       0.91      0.92      0.92      1145
#
#     accuracy                           0.92      2352
#    macro avg       0.92      0.92      0.92      2352
# weighted avg       0.92      0.92      0.92      2352

# %%
def predictor(text, model, vocab=ft_model.wv.vocab, maxlen=max_len):
  pattern = re.compile('[^ㄱ-ㅎㅏ-ㅣ가-힣]')
  text = re.sub(pattern, ' ', text)
  tokenized = text_tokenize(text)
  tokenized_padded = pad_sequences(sequences=vectorize_data(tokenized, vocab=vocab), maxlen=maxlen, padding='post')

  print("Regexed Text:         ", text)
  print("Tokenized Text:       ", tokenized)
  ratio = round(model.predict(tokenized_padded)[0][0] * 100, 2)
  print(f'{ratio}% 확률로 욕설 문장입니다.')
  print('----------------------------------------')
  print('욕설 부분 분석\n')
  badword_list = []
  for idx, token in enumerate(tokenized[0]):
    pad_token = pad_sequences(sequences=vectorize_data([[token]], vocab=ft_model.wv.vocab), maxlen=35, padding='post')
    token_ratio = round(model.predict(pad_token)[0][0] * 100, 2)
    print(token + '\t: ' + str(token_ratio) +'% 확률로 욕설 부분')
    if token_ratio > 50:
      badword_list.append(token)
  
  return badword_list

# %%
def masker(text, badword):
  masked_text = text
  for bad in badword:
    masked_text = masked_text.replace(bad, '*' * len(bad), 1)
  
  return masked_text

# %%
text='이 프로그램이 우리 계획의 시발점이다. '

print('1DCNN MODEL')
badword = predictor(text, cnn)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('BILSTM MODEL')
badword = predictor(text, bilstm)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('DOUBLE BILSTM MODEL')
badword = predictor(text, bilstm_dbl)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('ATTENTION MODEL')
badword = predictor(text, attention)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
# Out:
# 1DCNN MODEL
# Regexed Text:          이 프로그램이 우리 계획의 시발점이다
# Tokenized Text:        [['이', '프로그램', '우리', '계획', '시발점']]
# 2.81% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 이	: 52.67% 확률로 욕설 부분
# 프로그램	: 7.34% 확률로 욕설 부분
# 우리	: 8.61% 확률로 욕설 부분
# 계획	: 36.86% 확률로 욕설 부분
# 시발점	: 34.3% 확률로 욕설 부분
#
#
# Original Text:  이 프로그램이 우리 계획의 시발점이다.
# Masked Text:    * 프로그램이 우리 계획의 시발점이다.
# --------------------------------------------------------------------------------
# BILSTM MODEL
# Regexed Text:          이 프로그램이 우리 계획의 시발점이다
# Tokenized Text:        [['이', '프로그램', '우리', '계획', '시발점']]
# 2.84% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 이	: 24.6% 확률로 욕설 부분
# 프로그램	: 4.62% 확률로 욕설 부분
# 우리	: 7.04% 확률로 욕설 부분
# 계획	: 5.51% 확률로 욕설 부분
# 시발점	: 19.49% 확률로 욕설 부분
#
#
# Original Text:  이 프로그램이 우리 계획의 시발점이다.
# Masked Text:    이 프로그램이 우리 계획의 시발점이다.
# --------------------------------------------------------------------------------
# DOUBLE BILSTM MODEL
# Regexed Text:          이 프로그램이 우리 계획의 시발점이다
# Tokenized Text:        [['이', '프로그램', '우리', '계획', '시발점']]
# 2.22% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 이	: 41.82% 확률로 욕설 부분
# 프로그램	: 2.9% 확률로 욕설 부분
# 우리	: 1.15% 확률로 욕설 부분
# 계획	: 0.73% 확률로 욕설 부분
# 시발점	: 3.97% 확률로 욕설 부분
#
#
# Original Text:  이 프로그램이 우리 계획의 시발점이다.
# Masked Text:    이 프로그램이 우리 계획의 시발점이다.
# --------------------------------------------------------------------------------
# ATTENTION MODEL
# Regexed Text:          이 프로그램이 우리 계획의 시발점이다
# Tokenized Text:        [['이', '프로그램', '우리', '계획', '시발점']]
# 8.77% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 이	: 17.63% 확률로 욕설 부분
# 프로그램	: 0.65% 확률로 욕설 부분
# 우리	: 1.91% 확률로 욕설 부분
# 계획	: 3.87% 확률로 욕설 부분
# 시발점	: 13.62% 확률로 욕설 부분
#
#
# Original Text:  이 프로그램이 우리 계획의 시발점이다.
# Masked Text:    이 프로그램이 우리 계획의 시발점이다.

# %%
text='아 씨발 진짜 개 좆같네'

print('1DCNN MODEL')
badword = predictor(text, cnn)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('BILSTM MODEL')
badword = predictor(text, bilstm)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('DOUBLE BILSTM MODEL')
badword = predictor(text, bilstm_dbl)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('ATTENTION MODEL')
badword = predictor(text, attention)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
# Out:
# 1DCNN MODEL
# Regexed Text:          아 씨발 진짜 개 좆같네
# Tokenized Text:        [['아', '씨발', '진짜', '개', '좆같']]
# 99.89% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 아	: 21.86% 확률로 욕설 부분
# 씨발	: 99.44% 확률로 욕설 부분
# 진짜	: 42.22% 확률로 욕설 부분
# 개	: 88.46% 확률로 욕설 부분
# 좆같	: 63.46% 확률로 욕설 부분
#
#
# Original Text:  아 씨발 진짜 개 좆같네
# Masked Text:    아 ** 진짜 * **네
# --------------------------------------------------------------------------------
# BILSTM MODEL
# Regexed Text:          아 씨발 진짜 개 좆같네
# Tokenized Text:        [['아', '씨발', '진짜', '개', '좆같']]
# 96.79% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 아	: 5.09% 확률로 욕설 부분
# 씨발	: 98.93% 확률로 욕설 부분
# 진짜	: 10.63% 확률로 욕설 부분
# 개	: 83.15% 확률로 욕설 부분
# 좆같	: 65.87% 확률로 욕설 부분
#
#
# Original Text:  아 씨발 진짜 개 좆같네
# Masked Text:    아 ** 진짜 * **네
# --------------------------------------------------------------------------------
# DOUBLE BILSTM MODEL
# Regexed Text:          아 씨발 진짜 개 좆같네
# Tokenized Text:        [['아', '씨발', '진짜', '개', '좆같']]
# 99.96% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 아	: 6.13% 확률로 욕설 부분
# 씨발	: 99.96% 확률로 욕설 부분
# 진짜	: 9.54% 확률로 욕설 부분
# 개	: 88.92% 확률로 욕설 부분
# 좆같	: 91.95% 확률로 욕설 부분
#
#
# Original Text:  아 씨발 진짜 개 좆같네
# Masked Text:    아 ** 진짜 * **네
# --------------------------------------------------------------------------------
# ATTENTION MODEL
# Regexed Text:          아 씨발 진짜 개 좆같네
# Tokenized Text:        [['아', '씨발', '진짜', '개', '좆같']]
# 99.73% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 아	: 4.61% 확률로 욕설 부분
# 씨발	: 99.59% 확률로 욕설 부분
# 진짜	: 5.28% 확률로 욕설 부분
# 개	: 79.34% 확률로 욕설 부분
# 좆같	: 88.95% 확률로 욕설 부분
#
#
# Original Text:  아 씨발 진짜 개 좆같네
# Masked Text:    아 ** 진짜 * **네
