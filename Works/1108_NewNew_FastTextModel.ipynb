# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# !pip install jamo
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 91 (delta 43), reused 22 (delta 6), pack-reused 0
# Unpacking objects: 100% (91/91), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# ...
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 86 kB 6.2 MB/s
# ...
#      |████████████████████████████████| 448 kB 69.3 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2021-11-09 01:47:51--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# ...

# %%
import pandas as pd

aihub = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2차년도4.csv', encoding='utf-8', header=None)

# %%
aihub.columns=['comments']

# %%
import re

pattern = re.compile('[^ㄱ-ㅎㅏ-ㅣ가-힣]')
unlabel_data1 = open('/content/drive/MyDrive/Colab Notebooks/data/unlabeled_comments_1.txt', 'r', encoding='utf-8')
unlabel_data2 = open('/content/drive/MyDrive/Colab Notebooks/data/unlabeled_comments_2.txt', 'r', encoding='utf-8')
unlabel_data3 = open('/content/drive/MyDrive/Colab Notebooks/data/unlabeled_comments_3.txt', 'r', encoding='utf-8')
unlabel_data4 = open('/content/drive/MyDrive/Colab Notebooks/data/unlabeled_comments_4.txt', 'r', encoding='utf-8')
unlabel_data5 = open('/content/drive/MyDrive/Colab Notebooks/data/unlabeled_comments_5.txt', 'r', encoding='utf-8')
text=[]

for d in unlabel_data1:
    d = d.strip()
    d = re.sub(pattern, ' ', d)
    text.append(d)
for d in unlabel_data2:
    d = d.strip()
    d = re.sub(pattern, ' ', d)
    text.append(d)
for d in unlabel_data3:
    d = d.strip()
    d = re.sub(pattern, ' ', d)
    text.append(d)
for d in unlabel_data4:
    d = d.strip()
    d = re.sub(pattern, ' ', d)
    text.append(d)
for d in unlabel_data5:
    d = d.strip()
    d = re.sub(pattern, ' ', d)
    text.append(d)

unlabel = pd.DataFrame({'comments': text})

# %%
aihub_samples = aihub.sample(1066107)

# %%
corpus = pd.concat([aihub_samples, unlabel])
corpus
# Out:
#                                                   comments
# 4964731                오늘까진국민어쩌고저쩌고하겠지,투표개표순간부터지들이왕이지 ㅋㅋㅋㅋ
# 5420597                김정은도야지~이번에 처형할놈은 기관포말고 방사포로 갈겨 죽이라우
# 5234238                              해봐 돼지새꺄... 아니 바퀴벌레 새꺄
# 6852484                                 작성자에 의해 삭제된 댓글입니다.
# 182251   ㅋㅋㅋ 문죄인이 김칫국부터 마시다 급체햇네 !!!추미애는 죄없다 다 문죄인이 시킨거...
# ...                                                    ...
# 2033888                                      오메 너무귀엽당
# 2033889                너무 예뿐 담호 ㅠㅠㅠㅠㅠㅠ 잘 보고 있어요 예쁜 필연부부
# 2033890                                  어머     예뻐라
# 2033891                                귀여워 역시 이쁘다 아가들 천사에요
# 2033892      정말 엄마 판박이네요   너무 귀여워요둘째는 잘생긴 아빠 닮은 딸 기대해보아요
#
# [3100000 rows x 1 columns]

# %%
corpus['comments'] = corpus['comments'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]','')

# %%
from konlpy.tag import Mecab
mecab = Mecab()

# %%
corpus.reset_index(drop=True, inplace=True)
corpus
# Out:
#                                                   comments
# 0                       오늘까진국민어쩌고저쩌고하겠지투표개표순간부터지들이왕이지 ㅋㅋㅋㅋ
# 1                       김정은도야지이번에 처형할놈은 기관포말고 방사포로 갈겨 죽이라우
# 2                                       해봐 돼지새꺄 아니 바퀴벌레 새꺄
# 3                                        작성자에 의해 삭제된 댓글입니다
# 4        ㅋㅋㅋ 문죄인이 김칫국부터 마시다 급체햇네 추미애는 죄없다 다 문죄인이 시킨거다 추...
# ...                                                    ...
# 3099995                                      오메 너무귀엽당
# 3099996                너무 예뿐 담호 ㅠㅠㅠㅠㅠㅠ 잘 보고 있어요 예쁜 필연부부
# 3099997                                  어머     예뻐라
# 3099998                                귀여워 역시 이쁘다 아가들 천사에요
# 3099999      정말 엄마 판박이네요   너무 귀여워요둘째는 잘생긴 아빠 닮은 딸 기대해보아요
#
# [3100000 rows x 1 columns]

# %%
def pos_delete(tag, pos):
  for p in pos:
    if (p not in tag) == False:
      if 'VV+' not in tag:
        return False
      else:
        return True
    else:
      continue
  
  return True
POS = ['CP', 'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ', 'JX', 'JC', 'JO', 'EP', 'EF', 'EC', 'ETN', 'ETM', 'VCP', 'VCN', 'SF', 'SY', 'XSN', 'XSV', 'XSA', 'XR']

# %%
sample = '씨발년아 아가리 안 닥쳐?'
print(sample)
ps = mecab.pos(sample)
print(ps)
tagged = []
tokenized=[]
for p in ps:
  if pos_delete(p[1], POS):
    tagged.append(p[0])
temp_X = [word for word in tagged]
tokenized.append(temp_X)
print(tokenized)
# Out:
# 씨발년아 아가리 안 닥쳐?
# [('씨발', 'IC'), ('년', 'NNB'), ('아', 'IC'), ('아가리', 'NNG'), ('안', 'MAG'), ('닥쳐', 'VV+EF'), ('?', 'SF')]
# [['씨발', '년', '아', '아가리', '안', '닥쳐']]

# %%
tokenized = []
count = 1

for sentence in corpus['comments']:
  print(count)
  ps = mecab.pos(sentence)
  tagged = []
  for p in ps:
    if pos_delete(p[1], POS):
      tagged.append(p[0])
  temp_X = [word for word in tagged]
  tokenized.append(temp_X)
  count+=1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 3095001
# 3095002
# 3095003
# 3095004
# 3095005
# 3095006
# 3095007
# 3095008
# 3095009
# 3095010
# 3095011
# 3095012
# 3095013
# 3095014
# 3095015
# 3095016
# 3095017
# 3095018
# 3095019
# 3095020
# 3095021
# 3095022
# 3095023
# 3095024
# 3095025
# 3095026
# 3095027
# 3095028
# 3095029
# 3095030
# 3095031
# 3095032
# 3095033
# 3095034
# 3095035
# 3095036
# 3095037
# 3095038
# 3095039
# 3095040
# 3095041
# 3095042
# 3095043
# 3095044
# 3095045
# 3095046
# 3095047
# 3095048
# 3095049
# 3095050
# 3095051
# 3095052
# 3095053
# 3095054
# 3095055
# 3095056
# 3095057
# 3095058
# 3095059
# 3095060
# 3095061
# 3095062
# 3095063
# 3095064
# 3095065
# 3095066
# 3095067
# 3095068
# 3095069
# 3095070
# 3095071
# 3095072
# 3095073
# 3095074
# 3095075
# 3095076
# 3095077
# 3095078
# 3095079
# 3095080
# 3095081
# 3095082
# 3095083
# 3095084
# 3095085
# 3095086
# 3095087
# 3095088
# 3095089
# 3095090
# 3095091
# 3095092
# 3095093
# 3095094
# 3095095
# 3095096
# ...

# %%
from gensim.models import FastText  
model = FastText(tokenized, size=100, window=2, min_count=3, workers=4, sg=1, min_n=3, max_n=6, iter=10)
model.save('/content/drive/MyDrive/Colab Notebooks/model/fasttext_310k_1109.model')

# %%
model.wv.most_similar('날먹')
# Out:
# [('알콩달콩', 0.9988680481910706),
#  ('행복', 0.743179202079773),
#  ('오래오래', 0.7044051289558411),
#  ('오순도순', 0.6971805095672607),
#  ('다복', 0.6903434991836548),
#  ('향복', 0.6813898086547852),
#  ('옙뻐', 0.6683944463729858),
#  ('천생배필', 0.6646766662597656),
#  ('심미나', 0.6594774723052979),
#  ('ㅠㅠ행복하게', 0.6540465354919434)]
