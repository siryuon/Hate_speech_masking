# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# !pip install adamp
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 91 (delta 0), reused 0 (delta 0), pack-reused 90
# Unpacking objects: 100% (91/91), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.4 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 42.8 MB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.0 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.10.0.2)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2021-11-19 06:22:26--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22cd:e0db, 2406:da00:ff00::22c0:3470, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=6Tx8%2FQqyGBdSbtOSbRBH2sc%2Bsms%3D&Expires=1637304504&AWSAccessKeyId=AKIA6KOSE3BNJRRFUUX6&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None [following]
# --2021-11-19 06:22:26--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=6Tx8%2FQqyGBdSbtOSbRBH2sc%2Bsms%3D&Expires=1637304504&AWSAccessKeyId=AKIA6KOSE3BNJRRFUUX6&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.130.11
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.130.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  --.-KB/s    in 0.1s
#
# 2021-11-19 06:22:27 (11.2 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2021-11-19 06:24:00--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22c0:3470, 2406:da00:ff00::22c5:2ef4, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=4QWiqRJ26%2BYgaeMELL3n6FtMias%3D&Expires=1637304587&AWSAccessKeyId=AKIA6KOSE3BNJRRFUUX6&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None [following]
# --2021-11-19 06:24:00--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=4QWiqRJ26%2BYgaeMELL3n6FtMias%3D&Expires=1637304587&AWSAccessKeyId=AKIA6KOSE3BNJRRFUUX6&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.217.206.57
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.217.206.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  86.6MB/s    in 0.5s
#
# 2021-11-19 06:24:01 (86.6 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# apt-get update
# apt-get upgrade
# apt install curl
# apt install git
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Done
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.
# Collecting adamp
#   Downloading adamp-0.3.0.tar.gz (5.1 kB)
# Building wheels for collected packages: adamp
#   Building wheel for adamp (setup.py) ... done
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5999 sha256=9d2b1a08ae5332801cf6a41e90eb3be15207c631d37fe93d9a810b684532447f
#   Stored in directory: /root/.cache/pip/wheels/bb/95/21/ced2d2cb9944e3a72e58fece7958973eed3fd8d0aeb6e2e450
# Successfully built adamp
# Installing collected packages: adamp
# Successfully installed adamp-0.3.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from adamp import AdamP
#from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
import warnings
warnings.filterwarnings('ignore')

import re
import seaborn as sb

# Tools for creating ngrams and vectorizing input data
from konlpy.tag import Mecab
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras import Input, Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional, Embedding, Conv1D, MaxPooling1D, BatchNormalization, Concatenate, Layer, GlobalMaxPool1D, GlobalMaxPooling1D, GlobalAveragePooling1D, GRU, SpatialDropout1D
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras import initializers, regularizers, constraints, optimizers, layers
import os
from keras import backend as K
from gensim.models import FastText
from sklearn.neighbors import NearestNeighbors

# %%
class Attention(Layer):
    def __init__(self, step_dim, W_regularizer=None, b_regularizer=None, W_constraint=None, b_constraint=None, bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim  

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
#Remove morphemes from specific parts-of-speech
def pos_delete(tag, pos):
  for p in pos:
    if (p not in tag) == False:
      if 'VV+' not in tag:
        return False
      else:
        return True
    else:
      continue
  
  return True

#Parts-of-speech list
POS = ['CP', 'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ', 'JX', 'JC', 'JO', 'EP', 'EF', 'EC', 'ETN', 'ETM', 'VCP', 'VCN', 'SF', 'SY', 'XSN', 'XSV', 'XSA', 'XR']

#Vectorized using a trained FastText model
def vectorize_data(data, vocab: dict) -> list:
  keys = list(vocab.keys())
  filter_unknown = lambda word: vocab.get(word, None) is not None
  result = []
  for d in data:
    filtered = list(filter(filter_unknown,d))
    res = []
    for f in filtered:
      res.append(vocab[f].index)
    result.append(res)
  
  return result

#Build model
def build_attention(embedding_matrix, maxlen):
  sequence_input = Input(shape=(maxlen,), dtype='int32')
  embedded_sequences = Embedding(embedding_matrix.shape[0], embedding_matrix.shape[1],  input_length=maxlen, weights=[embedding_matrix], trainable=False)(sequence_input)
  dropout_1 = SpatialDropout1D(0.1)(embedded_sequences)
  bilstm = Bidirectional(LSTM(32, return_sequences=True))(dropout_1)
  bigru = Bidirectional(GRU(32, return_sequences=True))(bilstm)

  atten_1 = Attention(maxlen)(bilstm)
  atten_2 = Attention(maxlen)(bigru)
  avg_pool = GlobalAveragePooling1D()(bigru)
  max_pool = GlobalMaxPooling1D()(bigru)

  conc = concatenate([atten_1, atten_2, avg_pool, max_pool])
  dense = Dense(16, activation='relu')(conc)
  dropout_2 = Dropout(0.1)(dense)
  output = Dense(1, activation='sigmoid')(dropout_2)

  model = Model(inputs=sequence_input, outputs=output)
  model.summary()

  return model

def build_1dcnn(embedding_matrix, maxlen):
    model = Sequential()
    model.add(Embedding(input_dim = embedding_matrix.shape[0], output_dim = embedding_matrix.shape[1],  input_length = maxlen, weights = [embedding_matrix], trainable=False))
    model.add(Dropout(0.2))
    model.add(Conv1D(50, 5, strides=1, padding='valid', activation='relu'))
    model.add(GlobalMaxPooling1D())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()

    return model

def build_bilstm(embedding_matrix, maxlen):
    model = Sequential()
    model.add(Embedding(input_dim = embedding_matrix.shape[0], output_dim = embedding_matrix.shape[1],  input_length = maxlen, weights = [embedding_matrix], trainable=False))
    model.add(Bidirectional(LSTM(128, recurrent_dropout=0.1)))
    model.add(Dropout(0.25))
    model.add(Dense(64))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()

    return model

def build_bilstm_dbl(embedding_matrix, maxlen):
    model = Sequential()
    model.add(Embedding(input_dim = embedding_matrix.shape[0], output_dim = embedding_matrix.shape[1],  input_length = maxlen, weights = [embedding_matrix], trainable=False))
    model.add(Bidirectional(LSTM(128, recurrent_dropout=0.1, return_sequences=True)))
    model.add(Bidirectional(LSTM(64, recurrent_dropout=0.1)))
    model.add(Dropout(0.25))
    model.add(Dense(64))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()

    return model
  
#Make synonym dictionary
def make_synonyms():
  synonyms_number = 5
  word_number = 20000
  embed_mat = ft_model.wv.vectors
  nn = NearestNeighbors(n_neighbors=synonyms_number+1).fit(embed_mat)
  neighbours_mat = nn.kneighbors(embed_mat[1:word_number])[1]
  nei_mat = []

  for i in range(len(neighbours_mat)):
    tmp = [ft_model.wv.index2word[s] for s in neighbours_mat[i]]
    nei_mat.append(tmp)

  synonyms = {nei[0]: nei[1:] for nei in nei_mat}

  return synonyms

#Modify train sentence with synonym dictionary
def modify_sentence(X_pos, synonyms, p=0.5):
    sentence = [ft_model.wv.index2word[x] for x in np.trim_zeros(X_pos)]
    for i in range(len(sentence)):
        if np.random.random() > p:
            try:
                syns = synonyms[sentence[i]]
                sentence[i] = np.random.choice(syns)
            except KeyError:
                pass
    return sentence

#Final function. Generate new hate sentence with synonym dictionary (with modify_sentence function)
def text_generator(X_pad, y_data, synonyms):
  X_pos = X_pad[y_data==1]
  n_texts = 15000
  indexes = np.random.randint(0, X_pos.shape[0], n_texts)
  
  X_gen = np.array([modify_sentence(x, synonyms) for x in X_pos[indexes]])
  y_gen = np.ones(n_texts)

  split_X_gen = []
  for i in range(len(X_gen)):
    split_X_gen.append([gen for gen in X_gen[i]])

  return split_X_gen, y_gen

#Text tokenize function (To use Predictor function)
def text_tokenize(text):
  mecab = Mecab()
  train_tokenized = []

  ps = mecab.pos(text)
  tagged = []
  for p in ps:
    if pos_delete(p[1], POS):
      tagged.append(p[0])
  temp_X = [word for word in tagged]
  train_tokenized.append(temp_X)

  return train_tokenized

#Visulaize confusion matrix
def plot_confusion_matrix(y_true, y_pred, ax, class_names, vmax=None,
                          normed=True, title='Confusion matrix'):
    matrix = confusion_matrix(y_true,y_pred)
    if normed:
        matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
    sb.heatmap(matrix, vmax=vmax, annot=True, square=True, ax=ax,
               cmap=plt.cm.Blues_r, cbar=False, linecolor='black',
               linewidths=1, xticklabels=class_names)
    ax.set_title(title, y=1.20, fontsize=16)
    ax.set_xlabel('Predicted labels', y=1.10, fontsize=12)
    ax.set_yticklabels(class_names, rotation=0)

#Convert to probability corresponding to each label
def predict_proba(pred):
  proba = []
  for i in range(len(pred)):
    proba.append([float(1-pred[i]), pred[i][0]])
  
  return proba

#Class prediction based on the transformed probability
def class_predict(proba):
  return np.argmax(proba, axis=1)

#Determine max_len function
def below_threshold_len(max_len, nested_list):
  count = 0
  for sentence in nested_list:
    if(len(sentence) <= max_len):
        count = count + 1
  print('Proportion of samples with length %s or less among all samples: %s'%(max_len, (count / len(nested_list))*100))

# %%
#Train data load +  Tagging + Spliting + FastText Model load
train_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/train_data.csv', encoding='cp949')
train_data['comments'] = train_data['comments'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]','')

mecab = Mecab()
train_tokenized = []

for comment in train_data['comments']:
  ps = mecab.pos(comment)
  tagged = []
  for p in ps:
    if pos_delete(p[1], POS):
      tagged.append(p[0])
    temp_X = [word for word in tagged]
  train_tokenized.append(temp_X)

ft_model = FastText.load('/content/drive/MyDrive/Colab Notebooks/model/fasttext_310k_1109.model')

# %%
#Make Synonyms dictionary
synonyms = make_synonyms()

# %%
#Define X_data and y_data
X_data = train_tokenized
y_data = train_data['hate'].values

# %%
#View Ratio Length
below_threshold_len(35, X_data)
# Out:
# Proportion of samples with length 35 or less among all samples: 98.89632936507937

# %%
#Comment Vectorize with FastText Model (train_data)
max_len = 35
padded_X = pad_sequences(
    sequences=vectorize_data(X_data, vocab=ft_model.wv.vocab),
    maxlen=max_len,
    padding='post'
)

# %%
#Generate Sentence with synonym dictionary
X_pos = padded_X[y_data==1]
split_X_gen, y_gen = text_generator(padded_X, y_data, synonyms)
mix_X = X_data + split_X_gen
mix_y = np.hstack((y_data, y_gen))

#Comment Vectorize with FastText Model (Generate_data)
max_len = 35
X_pad = pad_sequences(
    sequences=vectorize_data(mix_X, vocab=ft_model.wv.vocab),
    maxlen=max_len,
    padding='post'
)

#Final Input data: X_pad(x_data), mix_y(y_data)

# %%
#Split train data, validation data and test data
X_train, X_vt, y_train, y_vt = train_test_split(X_pad, mix_y, test_size=0.2, shuffle=True, random_state=42)
X_valid, X_test, y_valid, y_test = train_test_split(X_vt, y_vt, test_size=0.3, shuffle=True, random_state=42)

# %%
#Define matrics(TP, FP, TN, FN, Accuracy, Precision, Recall, AUC)
METRICS = [
    keras.metrics.BinaryAccuracy(name='accuracy'),
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

# %%
#Model define and train, visualize model tree
attention = build_attention(embedding_matrix=ft_model.wv.vectors, maxlen=max_len)
cnn = build_1dcnn(embedding_matrix=ft_model.wv.vectors, maxlen=max_len)
bilstm = build_bilstm(embedding_matrix=ft_model.wv.vectors, maxlen=max_len)
bilstm_dbl = build_bilstm_dbl(embedding_matrix=ft_model.wv.vectors, maxlen=max_len)

attention.compile(loss='binary_crossentropy', optimizer='nadam', metrics=METRICS)
cnn.compile(loss='binary_crossentropy', optimizer='nadam', metrics=METRICS)
bilstm.compile(loss='binary_crossentropy', optimizer='nadam', metrics=METRICS)
bilstm_dbl.compile(loss='binary_crossentropy', optimizer='nadam', metrics=METRICS)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 35)]         0           []
#
#  embedding_20 (Embedding)       (None, 35, 100)      9236500     ['input_6[0][0]']
#
#  spatial_dropout1d_5 (SpatialDr  (None, 35, 100)     0           ['embedding_20[0][0]']
#  opout1D)
#
#  bidirectional_25 (Bidirectiona  (None, 35, 64)      34048       ['spatial_dropout1d_5[0][0]']
#  l)
#
#  bidirectional_26 (Bidirectiona  (None, 35, 64)      18816       ['bidirectional_25[0][0]']
#  l)
#
#  attention_10 (Attention)       (None, 64)           99          ['bidirectional_25[0][0]']
#
#  attention_11 (Attention)       (None, 64)           99          ['bidirectional_26[0][0]']
#
#  global_average_pooling1d_5 (Gl  (None, 64)          0           ['bidirectional_26[0][0]']
#  obalAveragePooling1D)
#
#  global_max_pooling1d_10 (Globa  (None, 64)          0           ['bidirectional_26[0][0]']
#  lMaxPooling1D)
#
#  concatenate_5 (Concatenate)    (None, 256)          0           ['attention_10[0][0]',
#                                                                   'attention_11[0][0]',
#                                                                   'global_average_pooling1d_5[0][0
#                                                                  ]',
#                                                                   'global_max_pooling1d_10[0][0]']
#
#  dense_40 (Dense)               (None, 16)           4112        ['concatenate_5[0][0]']
#
#  dropout_35 (Dropout)           (None, 16)           0           ['dense_40[0][0]']
#
#  dense_41 (Dense)               (None, 1)            17          ['dropout_35[0][0]']
#
# ==================================================================================================
# Total params: 9,293,691
# Trainable params: 57,191
# Non-trainable params: 9,236,500
# __________________________________________________________________________________________________
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_21 (Embedding)    (None, 35, 100)           9236500
#
#  dropout_36 (Dropout)        (None, 35, 100)           0
#
#  conv1d_5 (Conv1D)           (None, 31, 50)            25050
#
#  global_max_pooling1d_11 (Gl  (None, 50)               0
#  obalMaxPooling1D)
#
#  dense_42 (Dense)            (None, 64)                3264
#
#  dropout_37 (Dropout)        (None, 64)                0
#
#  dense_43 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 9,264,879
# Trainable params: 28,379
# Non-trainable params: 9,236,500
# _________________________________________________________________
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_22 (Embedding)    (None, 35, 100)           9236500
#
#  bidirectional_27 (Bidirecti  (None, 256)              234496
#  onal)
#
#  dropout_38 (Dropout)        (None, 256)               0
#
#  dense_44 (Dense)            (None, 64)                16448
#
#  dropout_39 (Dropout)        (None, 64)                0
#
#  dense_45 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 9,487,509
# Trainable params: 251,009
# Non-trainable params: 9,236,500
# _________________________________________________________________
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_23 (Embedding)    (None, 35, 100)           9236500
#
#  bidirectional_28 (Bidirecti  (None, 35, 256)          234496
#  onal)
#
#  bidirectional_29 (Bidirecti  (None, 128)              164352
#  onal)
#
#  dropout_40 (Dropout)        (None, 128)               0
#
#  dense_46 (Dense)            (None, 64)                8256
#
#  dropout_41 (Dropout)        (None, 64)                0
#
#  dense_47 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 9,643,669
# Trainable params: 407,169
# Non-trainable params: 9,236,500
# _________________________________________________________________

# %%
keras.utils.plot_model(attention, show_shapes=True, dpi=90)

# %%
keras.utils.plot_model(cnn, show_shapes=True, dpi=90)

# %%
keras.utils.plot_model(bilstm, show_shapes=True, dpi=90)

# %%
keras.utils.plot_model(bilstm_dbl, show_shapes=True, dpi=90)

# %%
EPOCHS=20
h_attention = attention.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=100, epochs=EPOCHS)
h_cnn = cnn.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=100, epochs=EPOCHS)
h_bilstm = bilstm.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=100, epochs=EPOCHS)
h_bilstm_dbl = bilstm_dbl.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=100, epochs=EPOCHS)

print('Model train complete.')
# Out:
# Epoch 1/20
# 314/314 [==============================] - 43s 106ms/step - loss: 0.4488 - accuracy: 0.8026 - precision: 0.8097 - recall: 0.7930 - val_loss: 0.3606 - val_accuracy: 0.8460 - val_precision: 0.8286 - val_recall: 0.8761
# Epoch 2/20
# 314/314 [==============================] - 31s 99ms/step - loss: 0.3684 - accuracy: 0.8396 - precision: 0.8368 - recall: 0.8461 - val_loss: 0.3478 - val_accuracy: 0.8493 - val_precision: 0.8053 - val_recall: 0.9249
# Epoch 3/20
# 314/314 [==============================] - 31s 99ms/step - loss: 0.3265 - accuracy: 0.8601 - precision: 0.8622 - recall: 0.8592 - val_loss: 0.2945 - val_accuracy: 0.8768 - val_precision: 0.8704 - val_recall: 0.8880
# Epoch 4/20
# 314/314 [==============================] - 31s 98ms/step - loss: 0.2868 - accuracy: 0.8794 - precision: 0.8821 - recall: 0.8775 - val_loss: 0.2909 - val_accuracy: 0.8808 - val_precision: 0.9336 - val_recall: 0.8223
# Epoch 5/20
# 314/314 [==============================] - 31s 100ms/step - loss: 0.2642 - accuracy: 0.8890 - precision: 0.8922 - recall: 0.8864 - val_loss: 0.2689 - val_accuracy: 0.8916 - val_precision: 0.8580 - val_recall: 0.9408
# Epoch 6/20
# 314/314 [==============================] - 31s 100ms/step - loss: 0.2420 - accuracy: 0.8994 - precision: 0.9013 - recall: 0.8982 - val_loss: 0.2563 - val_accuracy: 0.8959 - val_precision: 0.8668 - val_recall: 0.9379
# Epoch 7/20
# 314/314 [==============================] - 31s 99ms/step - loss: 0.2283 - accuracy: 0.9055 - precision: 0.9081 - recall: 0.9034 - val_loss: 0.2468 - val_accuracy: 0.8994 - val_precision: 0.8929 - val_recall: 0.9097
# Epoch 8/20
# 314/314 [==============================] - 31s 100ms/step - loss: 0.2154 - accuracy: 0.9124 - precision: 0.9160 - recall: 0.9093 - val_loss: 0.2271 - val_accuracy: 0.9083 - val_precision: 0.9096 - val_recall: 0.9086
# Epoch 9/20
# 314/314 [==============================] - 31s 99ms/step - loss: 0.2013 - accuracy: 0.9197 - precision: 0.9244 - recall: 0.9151 - val_loss: 0.2407 - val_accuracy: 0.9032 - val_precision: 0.8745 - val_recall: 0.9437
# Epoch 10/20
# 314/314 [==============================] - 31s 99ms/step - loss: 0.1934 - accuracy: 0.9227 - precision: 0.9241 - recall: 0.9219 - val_loss: 0.2275 - val_accuracy: 0.9089 - val_precision: 0.8895 - val_recall: 0.9357
# Epoch 11/20
# 314/314 [==============================] - 31s 100ms/step - loss: 0.1859 - accuracy: 0.9257 - precision: 0.9297 - recall: 0.9219 - val_loss: 0.2199 - val_accuracy: 0.9122 - val_precision: 0.9017 - val_recall: 0.9270
# Epoch 12/20
# 314/314 [==============================] - 31s 99ms/step - loss: 0.1783 - accuracy: 0.9292 - precision: 0.9324 - recall: 0.9264 - val_loss: 0.2354 - val_accuracy: 0.9069 - val_precision: 0.8776 - val_recall: 0.9476
# Epoch 13/20
# 314/314 [==============================] - 31s 100ms/step - loss: 0.1714 - accuracy: 0.9321 - precision: 0.9336 - recall: 0.9312 - val_loss: 0.2199 - val_accuracy: 0.9162 - val_precision: 0.9234 - val_recall: 0.9094
# Epoch 14/20
# 314/314 [==============================] - 32s 100ms/step - loss: 0.1637 - accuracy: 0.9350 - precision: 0.9374 - recall: 0.9330 - val_loss: 0.2427 - val_accuracy: 0.9078 - val_precision: 0.8723 - val_recall: 0.9574
# Epoch 15/20
# 314/314 [==============================] - 31s 100ms/step - loss: 0.1570 - accuracy: 0.9377 - precision: 0.9391 - recall: 0.9370 - val_loss: 0.2388 - val_accuracy: 0.9074 - val_precision: 0.8800 - val_recall: 0.9455
# Epoch 16/20
# 314/314 [==============================] - 31s 98ms/step - loss: 0.1485 - accuracy: 0.9430 - precision: 0.9442 - recall: 0.9423 - val_loss: 0.2208 - val_accuracy: 0.9129 - val_precision: 0.8927 - val_recall: 0.9404
# Epoch 17/20
# 314/314 [==============================] - 31s 98ms/step - loss: 0.1423 - accuracy: 0.9449 - precision: 0.9461 - recall: 0.9442 - val_loss: 0.2260 - val_accuracy: 0.9142 - val_precision: 0.8922 - val_recall: 0.9440
# Epoch 18/20
# 314/314 [==============================] - 31s 99ms/step - loss: 0.1380 - accuracy: 0.9465 - precision: 0.9471 - recall: 0.9465 - val_loss: 0.2703 - val_accuracy: 0.9023 - val_precision: 0.8629 - val_recall: 0.9588
# Epoch 19/20
# 314/314 [==============================] - 31s 98ms/step - loss: 0.1354 - accuracy: 0.9468 - precision: 0.9469 - recall: 0.9473 - val_loss: 0.2589 - val_accuracy: 0.9060 - val_precision: 0.8707 - val_recall: 0.9556
# Epoch 20/20
# 314/314 [==============================] - 31s 98ms/step - loss: 0.1260 - accuracy: 0.9507 - precision: 0.9521 - recall: 0.9497 - val_loss: 0.2142 - val_accuracy: 0.9180 - val_precision: 0.9227 - val_recall: 0.9140
# Epoch 1/20
# 314/314 [==============================] - 9s 26ms/step - loss: 0.4570 - accuracy: 0.8043 - precision: 0.8120 - recall: 0.7953 - val_loss: 0.3672 - val_accuracy: 0.8476 - val_precision: 0.8115 - val_recall: 0.9094
# Epoch 2/20
# 314/314 [==============================] - 8s 25ms/step - loss: 0.3612 - accuracy: 0.8444 - precision: 0.8437 - recall: 0.8475 - val_loss: 0.3306 - val_accuracy: 0.8631 - val_precision: 0.8238 - val_recall: 0.9270
# Epoch 3/20
# 314/314 [==============================] - 8s 24ms/step - loss: 0.3227 - accuracy: 0.8625 - precision: 0.8622 - recall: 0.8647 - val_loss: 0.3056 - val_accuracy: 0.8712 - val_precision: 0.8483 - val_recall: 0.9068
# Epoch 4/20
# 314/314 [==============================] - 8s 24ms/step - loss: 0.2965 - accuracy: 0.8737 - precision: 0.8728 - recall: 0.8767 - val_loss: 0.2879 - val_accuracy: 0.8770 - val_precision: 0.8462 - val_recall: 0.9242
# Epoch 5/20
# 314/314 [==============================] - 8s 24ms/step - loss: 0.2739 - accuracy: 0.8860 - precision: 0.8857 - recall: 0.8880 - val_loss: 0.2728 - val_accuracy: 0.8815 - val_precision: 0.8627 - val_recall: 0.9101
# Epoch 6/20
# 314/314 [==============================] - 8s 24ms/step - loss: 0.2560 - accuracy: 0.8925 - precision: 0.8935 - recall: 0.8926 - val_loss: 0.2767 - val_accuracy: 0.8828 - val_precision: 0.8492 - val_recall: 0.9336
# Epoch 7/20
# 314/314 [==============================] - 8s 25ms/step - loss: 0.2419 - accuracy: 0.8992 - precision: 0.9007 - recall: 0.8986 - val_loss: 0.2774 - val_accuracy: 0.8861 - val_precision: 0.8490 - val_recall: 0.9419
# Epoch 8/20
# 314/314 [==============================] - 8s 24ms/step - loss: 0.2298 - accuracy: 0.9064 - precision: 0.9069 - recall: 0.9069 - val_loss: 0.2874 - val_accuracy: 0.8808 - val_precision: 0.8382 - val_recall: 0.9466
# Epoch 9/20
# 314/314 [==============================] - 8s 24ms/step - loss: 0.2159 - accuracy: 0.9112 - precision: 0.9139 - recall: 0.9090 - val_loss: 0.3304 - val_accuracy: 0.8660 - val_precision: 0.8087 - val_recall: 0.9621
# Epoch 10/20
# 314/314 [==============================] - 8s 24ms/step - loss: 0.2088 - accuracy: 0.9148 - precision: 0.9159 - recall: 0.9144 - val_loss: 0.3190 - val_accuracy: 0.8717 - val_precision: 0.8155 - val_recall: 0.9639
# Epoch 11/20
# 314/314 [==============================] - 8s 24ms/step - loss: 0.1998 - accuracy: 0.9186 - precision: 0.9215 - recall: 0.9162 - val_loss: 0.2549 - val_accuracy: 0.8970 - val_precision: 0.8678 - val_recall: 0.9390
# Epoch 12/20
# 314/314 [==============================] - 8s 25ms/step - loss: 0.1976 - accuracy: 0.9191 - precision: 0.9211 - recall: 0.9177 - val_loss: 0.3344 - val_accuracy: 0.8713 - val_precision: 0.8123 - val_recall: 0.9689
# Epoch 13/20
# 314/314 [==============================] - 8s 24ms/step - loss: 0.1912 - accuracy: 0.9228 - precision: 0.9249 - recall: 0.9212 - val_loss: 0.2918 - val_accuracy: 0.8824 - val_precision: 0.8333 - val_recall: 0.9588
# Epoch 14/20
# 314/314 [==============================] - 8s 25ms/step - loss: 0.1888 - accuracy: 0.9239 - precision: 0.9254 - recall: 0.9231 - val_loss: 0.3308 - val_accuracy: 0.8732 - val_precision: 0.8165 - val_recall: 0.9657
# Epoch 15/20
# 314/314 [==============================] - 8s 25ms/step - loss: 0.1783 - accuracy: 0.9275 - precision: 0.9303 - recall: 0.9251 - val_loss: 0.2618 - val_accuracy: 0.8958 - val_precision: 0.8710 - val_recall: 0.9314
# Epoch 16/20
# 314/314 [==============================] - 8s 25ms/step - loss: 0.1768 - accuracy: 0.9285 - precision: 0.9299 - recall: 0.9276 - val_loss: 0.3262 - val_accuracy: 0.8823 - val_precision: 0.8327 - val_recall: 0.9596
# Epoch 17/20
# 314/314 [==============================] - 8s 25ms/step - loss: 0.1725 - accuracy: 0.9296 - precision: 0.9324 - recall: 0.9271 - val_loss: 0.2956 - val_accuracy: 0.8863 - val_precision: 0.8432 - val_recall: 0.9516
# Epoch 18/20
# 314/314 [==============================] - 8s 25ms/step - loss: 0.1723 - accuracy: 0.9299 - precision: 0.9327 - recall: 0.9276 - val_loss: 0.3113 - val_accuracy: 0.8850 - val_precision: 0.8353 - val_recall: 0.9617
# Epoch 19/20
# 314/314 [==============================] - 8s 25ms/step - loss: 0.1669 - accuracy: 0.9341 - precision: 0.9365 - recall: 0.9321 - val_loss: 0.3007 - val_accuracy: 0.8912 - val_precision: 0.8490 - val_recall: 0.9541
# Epoch 20/20
# 314/314 [==============================] - 8s 24ms/step - loss: 0.1681 - accuracy: 0.9319 - precision: 0.9342 - recall: 0.9300 - val_loss: 0.3630 - val_accuracy: 0.8690 - val_precision: 0.8076 - val_recall: 0.9718
# Epoch 1/20
# 314/314 [==============================] - 95s 280ms/step - loss: 0.4250 - accuracy: 0.8126 - precision: 0.8092 - recall: 0.8210 - val_loss: 0.4039 - val_accuracy: 0.8203 - val_precision: 0.8996 - val_recall: 0.7248
# Epoch 2/20
# 314/314 [==============================] - 88s 280ms/step - loss: 0.3547 - accuracy: 0.8452 - precision: 0.8467 - recall: 0.8451 - val_loss: 0.3327 - val_accuracy: 0.8624 - val_precision: 0.8470 - val_recall: 0.8877
# Epoch 3/20
# 314/314 [==============================] - 87s 279ms/step - loss: 0.3222 - accuracy: 0.8608 - precision: 0.8619 - recall: 0.8611 - val_loss: 0.3048 - val_accuracy: 0.8675 - val_precision: 0.8743 - val_recall: 0.8613
# Epoch 4/20
# 314/314 [==============================] - 88s 279ms/step - loss: 0.2871 - accuracy: 0.8766 - precision: 0.8793 - recall: 0.8745 - val_loss: 0.2975 - val_accuracy: 0.8724 - val_precision: 0.9294 - val_recall: 0.8086
# Epoch 5/20
# 314/314 [==============================] - 87s 278ms/step - loss: 0.2600 - accuracy: 0.8903 - precision: 0.8930 - recall: 0.8882 - val_loss: 0.2612 - val_accuracy: 0.8912 - val_precision: 0.9200 - val_recall: 0.8592
# Epoch 6/20
# 314/314 [==============================] - 87s 278ms/step - loss: 0.2358 - accuracy: 0.9047 - precision: 0.9094 - recall: 0.9002 - val_loss: 0.2759 - val_accuracy: 0.8916 - val_precision: 0.9190 - val_recall: 0.8610
# Epoch 7/20
# 314/314 [==============================] - 87s 279ms/step - loss: 0.2180 - accuracy: 0.9106 - precision: 0.9144 - recall: 0.9071 - val_loss: 0.2400 - val_accuracy: 0.9027 - val_precision: 0.9131 - val_recall: 0.8920
# Epoch 8/20
# 314/314 [==============================] - 88s 279ms/step - loss: 0.2720 - accuracy: 0.8892 - precision: 0.8898 - recall: 0.8900 - val_loss: 0.2490 - val_accuracy: 0.8963 - val_precision: 0.9274 - val_recall: 0.8620
# Epoch 9/20
# 314/314 [==============================] - 88s 280ms/step - loss: 0.2140 - accuracy: 0.9106 - precision: 0.9127 - recall: 0.9090 - val_loss: 0.2459 - val_accuracy: 0.9012 - val_precision: 0.9274 - val_recall: 0.8725
# Epoch 10/20
# 314/314 [==============================] - 88s 280ms/step - loss: 0.1998 - accuracy: 0.9177 - precision: 0.9217 - recall: 0.9140 - val_loss: 0.2303 - val_accuracy: 0.9089 - val_precision: 0.9002 - val_recall: 0.9216
# Epoch 11/20
# 314/314 [==============================] - 87s 276ms/step - loss: 0.1866 - accuracy: 0.9241 - precision: 0.9271 - recall: 0.9216 - val_loss: 0.2304 - val_accuracy: 0.9071 - val_precision: 0.9100 - val_recall: 0.9054
# Epoch 12/20
# 314/314 [==============================] - 88s 281ms/step - loss: 0.1765 - accuracy: 0.9279 - precision: 0.9307 - recall: 0.9257 - val_loss: 0.2523 - val_accuracy: 0.9043 - val_precision: 0.9332 - val_recall: 0.8729
# Epoch 13/20
# 314/314 [==============================] - 87s 277ms/step - loss: 0.1704 - accuracy: 0.9298 - precision: 0.9337 - recall: 0.9261 - val_loss: 0.2475 - val_accuracy: 0.9069 - val_precision: 0.9126 - val_recall: 0.9018
# Epoch 14/20
# 314/314 [==============================] - 87s 277ms/step - loss: 0.1622 - accuracy: 0.9324 - precision: 0.9361 - recall: 0.9290 - val_loss: 0.2330 - val_accuracy: 0.9091 - val_precision: 0.9207 - val_recall: 0.8971
# Epoch 15/20
# 314/314 [==============================] - 87s 277ms/step - loss: 0.1543 - accuracy: 0.9373 - precision: 0.9418 - recall: 0.9329 - val_loss: 0.2472 - val_accuracy: 0.9125 - val_precision: 0.9023 - val_recall: 0.9270
# Epoch 16/20
# 314/314 [==============================] - 87s 276ms/step - loss: 0.1488 - accuracy: 0.9402 - precision: 0.9440 - recall: 0.9367 - val_loss: 0.2340 - val_accuracy: 0.9125 - val_precision: 0.9148 - val_recall: 0.9115
# Epoch 17/20
# 314/314 [==============================] - 87s 278ms/step - loss: 0.1396 - accuracy: 0.9437 - precision: 0.9460 - recall: 0.9418 - val_loss: 0.2650 - val_accuracy: 0.9050 - val_precision: 0.9436 - val_recall: 0.8635
# Epoch 18/20
# 314/314 [==============================] - 87s 277ms/step - loss: 0.1324 - accuracy: 0.9462 - precision: 0.9489 - recall: 0.9439 - val_loss: 0.2534 - val_accuracy: 0.9109 - val_precision: 0.9213 - val_recall: 0.9003
# Epoch 19/20
# 314/314 [==============================] - 88s 279ms/step - loss: 0.1268 - accuracy: 0.9485 - precision: 0.9513 - recall: 0.9460 - val_loss: 0.2471 - val_accuracy: 0.9151 - val_precision: 0.9305 - val_recall: 0.8989
# Epoch 20/20
# 314/314 [==============================] - 87s 278ms/step - loss: 0.1201 - accuracy: 0.9518 - precision: 0.9545 - recall: 0.9494 - val_loss: 0.2607 - val_accuracy: 0.9165 - val_precision: 0.9134 - val_recall: 0.9220
# Epoch 1/20
# 314/314 [==============================] - 167s 496ms/step - loss: 0.4100 - accuracy: 0.8305 - precision: 0.8279 - recall: 0.8372 - val_loss: 0.3641 - val_accuracy: 0.8420 - val_precision: 0.8538 - val_recall: 0.8288
# Epoch 2/20
# 314/314 [==============================] - 155s 495ms/step - loss: 0.3396 - accuracy: 0.8543 - precision: 0.8511 - recall: 0.8610 - val_loss: 0.3163 - val_accuracy: 0.8666 - val_precision: 0.8367 - val_recall: 0.9140
# Epoch 3/20
# 314/314 [==============================] - 157s 501ms/step - loss: 0.2876 - accuracy: 0.8783 - precision: 0.8791 - recall: 0.8789 - val_loss: 0.2731 - val_accuracy: 0.8899 - val_precision: 0.8892 - val_recall: 0.8931
# Epoch 4/20
# 314/314 [==============================] - 156s 497ms/step - loss: 0.2487 - accuracy: 0.8969 - precision: 0.8996 - recall: 0.8948 - val_loss: 0.2595 - val_accuracy: 0.8983 - val_precision: 0.9108 - val_recall: 0.8852
# Epoch 5/20
# 314/314 [==============================] - 154s 491ms/step - loss: 0.2230 - accuracy: 0.9068 - precision: 0.9123 - recall: 0.9012 - val_loss: 0.2473 - val_accuracy: 0.9025 - val_precision: 0.8936 - val_recall: 0.9159
# Epoch 6/20
# 314/314 [==============================] - 155s 493ms/step - loss: 0.2011 - accuracy: 0.9173 - precision: 0.9232 - recall: 0.9113 - val_loss: 0.2931 - val_accuracy: 0.8795 - val_precision: 0.9587 - val_recall: 0.7956
# Epoch 7/20
# 314/314 [==============================] - 154s 492ms/step - loss: 0.1822 - accuracy: 0.9265 - precision: 0.9321 - recall: 0.9208 - val_loss: 0.2365 - val_accuracy: 0.9061 - val_precision: 0.8941 - val_recall: 0.9234
# Epoch 8/20
# 314/314 [==============================] - 154s 492ms/step - loss: 0.1667 - accuracy: 0.9328 - precision: 0.9361 - recall: 0.9298 - val_loss: 0.2361 - val_accuracy: 0.9078 - val_precision: 0.8997 - val_recall: 0.9198
# Epoch 9/20
# 314/314 [==============================] - 154s 490ms/step - loss: 0.1924 - accuracy: 0.9209 - precision: 0.9238 - recall: 0.9186 - val_loss: 0.2995 - val_accuracy: 0.8792 - val_precision: 0.9651 - val_recall: 0.7891
# Epoch 10/20
# 314/314 [==============================] - 154s 490ms/step - loss: 0.1453 - accuracy: 0.9418 - precision: 0.9448 - recall: 0.9391 - val_loss: 0.2837 - val_accuracy: 0.8927 - val_precision: 0.9534 - val_recall: 0.8277
# Epoch 11/20
# 314/314 [==============================] - 153s 489ms/step - loss: 0.1305 - accuracy: 0.9479 - precision: 0.9513 - recall: 0.9448 - val_loss: 0.2517 - val_accuracy: 0.9072 - val_precision: 0.9030 - val_recall: 0.9144
# Epoch 12/20
# 314/314 [==============================] - 153s 488ms/step - loss: 0.1215 - accuracy: 0.9520 - precision: 0.9540 - recall: 0.9503 - val_loss: 0.2525 - val_accuracy: 0.9091 - val_precision: 0.9254 - val_recall: 0.8917
# Epoch 13/20
# 314/314 [==============================] - 153s 488ms/step - loss: 0.1111 - accuracy: 0.9564 - precision: 0.9583 - recall: 0.9549 - val_loss: 0.2742 - val_accuracy: 0.9078 - val_precision: 0.9278 - val_recall: 0.8862
# Epoch 14/20
# 314/314 [==============================] - 154s 489ms/step - loss: 0.1012 - accuracy: 0.9600 - precision: 0.9616 - recall: 0.9587 - val_loss: 0.2664 - val_accuracy: 0.9114 - val_precision: 0.9283 - val_recall: 0.8935
# Epoch 15/20
# 314/314 [==============================] - 153s 489ms/step - loss: 0.0933 - accuracy: 0.9627 - precision: 0.9649 - recall: 0.9607 - val_loss: 0.2645 - val_accuracy: 0.9118 - val_precision: 0.9183 - val_recall: 0.9057
# Epoch 16/20
# 314/314 [==============================] - 154s 489ms/step - loss: 0.0870 - accuracy: 0.9660 - precision: 0.9672 - recall: 0.9651 - val_loss: 0.3217 - val_accuracy: 0.9154 - val_precision: 0.8992 - val_recall: 0.9375
# Epoch 17/20
# 314/314 [==============================] - 154s 489ms/step - loss: 0.0786 - accuracy: 0.9696 - precision: 0.9718 - recall: 0.9677 - val_loss: 0.3369 - val_accuracy: 0.9094 - val_precision: 0.9040 - val_recall: 0.9180
# Epoch 18/20
# 314/314 [==============================] - 153s 488ms/step - loss: 0.0756 - accuracy: 0.9698 - precision: 0.9712 - recall: 0.9687 - val_loss: 0.3112 - val_accuracy: 0.9112 - val_precision: 0.9226 - val_recall: 0.8996
# Epoch 19/20
# 314/314 [==============================] - 154s 491ms/step - loss: 0.0716 - accuracy: 0.9717 - precision: 0.9732 - recall: 0.9704 - val_loss: 0.3411 - val_accuracy: 0.9111 - val_precision: 0.9176 - val_recall: 0.9050
# Epoch 20/20
# 314/314 [==============================] - 155s 493ms/step - loss: 0.0619 - accuracy: 0.9766 - precision: 0.9782 - recall: 0.9751 - val_loss: 0.3599 - val_accuracy: 0.9162 - val_precision: 0.9297 - val_recall: 0.9021
# Model train complete.

# %%
train_pred_a = attention.predict(X_train)
test_pred_a = attention.predict(X_test)
train_pred_c = cnn.predict(X_train)
test_pred_c = cnn.predict(X_test)
train_pred_b = bilstm.predict(X_train)
test_pred_b = bilstm.predict(X_test)
train_pred_bd = bilstm_dbl.predict(X_train)
test_pred_bd = bilstm_dbl.predict(X_test)

train_pred_proba_a = predict_proba(train_pred_a)
test_pred_proba_a = predict_proba(test_pred_a)
train_pred_proba_c = predict_proba(train_pred_c)
test_pred_proba_c = predict_proba(test_pred_c)
train_pred_proba_b = predict_proba(train_pred_b)
test_pred_proba_b = predict_proba(test_pred_b)
train_pred_proba_bd = predict_proba(train_pred_bd)
test_pred_proba_bd = predict_proba(test_pred_bd)

train_preds_a = class_predict(train_pred_proba_a)
test_preds_a = class_predict(test_pred_proba_a)
train_preds_c = class_predict(train_pred_proba_c)
test_preds_c = class_predict(test_pred_proba_c)
train_preds_b = class_predict(train_pred_proba_b)
test_preds_b = class_predict(test_pred_proba_b)
train_preds_bd = class_predict(train_pred_proba_bd)
test_preds_bd = class_predict(test_pred_proba_bd)

print('Data predict complete.')
# Out:
# Data predict complete.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (classification_report,
                             confusion_matrix,
                             roc_auc_score)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

report_a = classification_report(y_test, test_preds_a)
report_c = classification_report(y_test, test_preds_c)
report_b = classification_report(y_test, test_preds_b)
report_bd = classification_report(y_test, test_preds_bd)
print('Attantion Model Classification Report')
print(report_a)
print('1D-CNN Model Classification Report')
print(report_c)
print('BiLSTM Model Classification Report')
print(report_b)
print('Double-BiLSTM Moded Classification Report')
print(report_bd)


def plot_cm(labels, predictions, name, p=0.5):
    cm = confusion_matrix(labels, predictions)
    plt.figure(figsize=(5, 5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title("Confusion matrix (" + name + ')')
    plt.ylabel("Actual label")
    plt.xlabel("Predicted label")
    
plot_cm(y_test, test_preds_a, 'Attention')
plot_cm(y_test, test_preds_c, '1D-CNN')
plot_cm(y_test, test_preds_b, 'BiLSTM')
plot_cm(y_test, test_preds_bd, 'Double BiLSTM')
# Out:
# Attantion Model Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93      1207
#          1.0       0.92      0.93      0.93      1145
#
#     accuracy                           0.93      2352
#    macro avg       0.93      0.93      0.93      2352
# weighted avg       0.93      0.93      0.93      2352
#
# 1D-CNN Model Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.76      0.86      1207
#          1.0       0.80      0.98      0.88      1145
#
#     accuracy                           0.87      2352
#    macro avg       0.88      0.87      0.87      2352
# weighted avg       0.89      0.87      0.87      2352
#
# BiLSTM Model Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.91      0.92      1207
#          1.0       0.90      0.93      0.92      1145
#
#     accuracy                           0.92      2352
#    macro avg       0.92      0.92      0.92      2352
# weighted avg       0.92      0.92      0.92      2352
#
# Double-BiLSTM Moded Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.94      0.93      1207
#          1.0       0.94      0.90      0.92      1145
#
#     accuracy                           0.92      2352
#    macro avg       0.92      0.92      0.92      2352
# weighted avg       0.92      0.92      0.92      2352

# %%
def predictor(text, model, vocab=ft_model.wv.vocab, maxlen=max_len):
  pattern = re.compile('[^ㄱ-ㅎㅏ-ㅣ가-힣]')
  text = re.sub(pattern, ' ', text)
  tokenized = text_tokenize(text)
  tokenized_padded = pad_sequences(sequences=vectorize_data(tokenized, vocab=vocab), maxlen=maxlen, padding='post')

  print("Regexed Text:         ", text)
  print("Tokenized Text:       ", tokenized)
  ratio = round(model.predict(tokenized_padded)[0][0] * 100, 2)
  print(f'{ratio}% 확률로 욕설 문장입니다.')
  print('----------------------------------------')
  print('욕설 부분 분석\n')
  badword_list = []
  for idx, token in enumerate(tokenized[0]):
    pad_token = pad_sequences(sequences=vectorize_data([[token]], vocab=ft_model.wv.vocab), maxlen=35, padding='post')
    token_ratio = round(model.predict(pad_token)[0][0] * 100, 2)
    print(token + '\t: ' + str(token_ratio) +'% 확률로 욕설 부분')
    if token_ratio > 50:
      badword_list.append(token)
  
  return badword_list

# %%
def masker(text, badword):
  masked_text = text
  for bad in badword:
    masked_text = masked_text.replace(bad, '*' * len(bad), 1)
  
  return masked_text

# %%
text='이 프로그램이 우리 계획의 시발점이다. '

print('1DCNN MODEL')
badword = predictor(text, cnn)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('BILSTM MODEL')
badword = predictor(text, bilstm)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('DOUBLE BILSTM MODEL')
badword = predictor(text, bilstm_dbl)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('ATTENTION MODEL')
badword = predictor(text, attention)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
# Out:
# 1DCNN MODEL
# Regexed Text:          이 프로그램이 우리 계획의 시발점이다
# Tokenized Text:        [['이', '프로그램', '우리', '계획', '시발점']]
# 0.83% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 이	: 43.68% 확률로 욕설 부분
# 프로그램	: 9.36% 확률로 욕설 부분
# 우리	: 41.48% 확률로 욕설 부분
# 계획	: 1.8% 확률로 욕설 부분
# 시발점	: 27.23% 확률로 욕설 부분
#
#
# Original Text:  이 프로그램이 우리 계획의 시발점이다.
# Masked Text:    이 프로그램이 우리 계획의 시발점이다.
# --------------------------------------------------------------------------------
# BILSTM MODEL
# Regexed Text:          이 프로그램이 우리 계획의 시발점이다
# Tokenized Text:        [['이', '프로그램', '우리', '계획', '시발점']]
# 0.01% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 이	: 27.73% 확률로 욕설 부분
# 프로그램	: 0.37% 확률로 욕설 부분
# 우리	: 1.73% 확률로 욕설 부분
# 계획	: 3.23% 확률로 욕설 부분
# 시발점	: 13.43% 확률로 욕설 부분
#
#
# Original Text:  이 프로그램이 우리 계획의 시발점이다.
# Masked Text:    이 프로그램이 우리 계획의 시발점이다.
# --------------------------------------------------------------------------------
# DOUBLE BILSTM MODEL
# Regexed Text:          이 프로그램이 우리 계획의 시발점이다
# Tokenized Text:        [['이', '프로그램', '우리', '계획', '시발점']]
# 0.0% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 이	: 18.57% 확률로 욕설 부분
# 프로그램	: 0.02% 확률로 욕설 부분
# 우리	: 0.11% 확률로 욕설 부분
# 계획	: 0.01% 확률로 욕설 부분
# 시발점	: 0.08% 확률로 욕설 부분
#
#
# Original Text:  이 프로그램이 우리 계획의 시발점이다.
# Masked Text:    이 프로그램이 우리 계획의 시발점이다.
# --------------------------------------------------------------------------------
# ATTENTION MODEL
# Regexed Text:          이 프로그램이 우리 계획의 시발점이다
# Tokenized Text:        [['이', '프로그램', '우리', '계획', '시발점']]
# 0.53% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 이	: 28.71% 확률로 욕설 부분
# 프로그램	: 0.4% 확률로 욕설 부분
# 우리	: 1.47% 확률로 욕설 부분
# 계획	: 0.39% 확률로 욕설 부분
# 시발점	: 50.29% 확률로 욕설 부분
#
#
# Original Text:  이 프로그램이 우리 계획의 시발점이다.
# Masked Text:    이 프로그램이 우리 계획의 ***이다.

# %%
text='아 씨발 진짜 개 좆같네'

print('1DCNN MODEL')
badword = predictor(text, cnn)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('BILSTM MODEL')
badword = predictor(text, bilstm)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('DOUBLE BILSTM MODEL')
badword = predictor(text, bilstm_dbl)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
print('-'*80)

print('ATTENTION MODEL')
badword = predictor(text, attention)
masked_text = masker(text, badword)
print('\n')
print("Original Text: ", text)
print("Masked Text:   ", masked_text)
# Out:
# 1DCNN MODEL
# Regexed Text:          아 씨발 진짜 개 좆같네
# Tokenized Text:        [['아', '씨발', '진짜', '개', '좆같']]
# 99.91% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 아	: 31.09% 확률로 욕설 부분
# 씨발	: 99.75% 확률로 욕설 부분
# 진짜	: 31.88% 확률로 욕설 부분
# 개	: 88.22% 확률로 욕설 부분
# 좆같	: 71.62% 확률로 욕설 부분
#
#
# Original Text:  아 씨발 진짜 개 좆같네
# Masked Text:    아 ** 진짜 * **네
# --------------------------------------------------------------------------------
# BILSTM MODEL
# Regexed Text:          아 씨발 진짜 개 좆같네
# Tokenized Text:        [['아', '씨발', '진짜', '개', '좆같']]
# 99.97% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 아	: 5.24% 확률로 욕설 부분
# 씨발	: 99.92% 확률로 욕설 부분
# 진짜	: 7.89% 확률로 욕설 부분
# 개	: 91.06% 확률로 욕설 부분
# 좆같	: 75.57% 확률로 욕설 부분
#
#
# Original Text:  아 씨발 진짜 개 좆같네
# Masked Text:    아 ** 진짜 * **네
# --------------------------------------------------------------------------------
# DOUBLE BILSTM MODEL
# Regexed Text:          아 씨발 진짜 개 좆같네
# Tokenized Text:        [['아', '씨발', '진짜', '개', '좆같']]
# 100.0% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 아	: 3.46% 확률로 욕설 부분
# 씨발	: 99.98% 확률로 욕설 부분
# 진짜	: 1.35% 확률로 욕설 부분
# 개	: 78.4% 확률로 욕설 부분
# 좆같	: 92.48% 확률로 욕설 부분
#
#
# Original Text:  아 씨발 진짜 개 좆같네
# Masked Text:    아 ** 진짜 * **네
# --------------------------------------------------------------------------------
# ATTENTION MODEL
# Regexed Text:          아 씨발 진짜 개 좆같네
# Tokenized Text:        [['아', '씨발', '진짜', '개', '좆같']]
# 99.75% 확률로 욕설 문장입니다.
# ----------------------------------------
# 욕설 부분 분석
#
# 아	: 2.61% 확률로 욕설 부분
# 씨발	: 99.62% 확률로 욕설 부분
# 진짜	: 4.43% 확률로 욕설 부분
# 개	: 81.81% 확률로 욕설 부분
# 좆같	: 90.25% 확률로 욕설 부분
#
#
# Original Text:  아 씨발 진짜 개 좆같네
# Masked Text:    아 ** 진짜 * **네
